# %%
import seaborn as sns
import numpy as np
import pandas as pd
import csv 
dataset = pd.read_csv(r'C:\Users\Lucas Tejedor\Desktop\Estudo_IA\novo.csv')

# %%
dataset.head()
# Out:
#                                              Condado     Estado   FIPS  \
# 0  Condado,United States,0,No,46,45.9,46.1,"157,3...        NaN    NaN
# 1                                       Perry County   Kentucky  21193
# 2                                      Powell County   Kentucky  21197
# 3                                North Slope Borough     Alaska   2185
# 4                                      Owsley County   Kentucky  21189
#
#   Met Objective of 45.5? (1) Age-Adjusted Death Rate  \
# 0                        NaN                     NaN
# 1                         No                   125.6
# 2                         No                   125.3
# 3                         No                   124.9
# 4                         No                   118.5
#
#   Lower 95% Confidence Interval for Death Rate  \
# 0                                          NaN
# 1                                        108.9
# 2                                        100.2
# ...

# %%
dataset = dataset.drop([0], axis=0).head()

# %%
clean_data = dataset

# %%
dataset = dataset.drop(columns="Estado")
dataset = dataset.drop(columns="Condado")
dataset = dataset.drop(columns="FIPS")
dataset = dataset.drop(columns="Upper 95% Confidence Interval for Trend;;;;;;;")
dataset = dataset.drop(columns="Met Objective of 45.5? (1)")
dataset = dataset.drop(columns="Recent 5-Year Trend (2) in Death Rates")
dataset = dataset.drop(columns="Lower 95% Confidence Interval for Trend")

# %%
dataset.head()
# Out:
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
# 5                   113.5                                         89.9
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                        144.2                      43
# 2                                        155.1                      18
# 3                                        194.7                       5
# 4                                        165.5                       8
# 5                                        141.4                      19
#
#   Recent Trend (2)
# 1           stable
# 2           stable
# 3               **
# 4           stable
# ...
